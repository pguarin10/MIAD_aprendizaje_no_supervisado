# %% [markdown]
# <div >
# <img src = "figs/ans_banner_1920x200.png" />
# </div>

# %% [markdown]
# # Descomposición en Valores Singulares. Interpretación Geométrica  y Ejercicios Teóricos.

# %% [markdown]
# Este *cuaderno* cubre detalles sobre el algebra de la descomposición en valores singulares. El objetivo del *cuaderno* es que aprenda la geometría que esta por detras de la SVD, el funcionamiento de la descomposición en valores singulares, y a construir e implementar este método. Al final encontrará ejercicios asociados a los contenidos del cuaderno para que los resuelva por su propia cuenta (no debe entregarlos).  Si tiene dudas sobre los contenidos o los ejercicios, consulte con el tutor.
#
#
# **NO** es necesario editar el archivo o hacer una entrega. Sin embargo, los ejemplos contienen celdas con código ejecutable (`en gris`), que podrá modificar  libremente. Esta puede ser una buena forma de aprender nuevas funcionalidades del *cuaderno*, o experimentar variaciones en los códigos de ejemplo.

# %% [markdown]
# ## Interpretación geométrica
#
# En el cuaderno *Descomposición en Valores Singulares. Fundamentos Teóricos.* mostramos que la SVD permite factorizar cualquier matriz real $X$ en 3 matrices, es decir, si tenemos una matrix real $X$ de dimensión $n\times k$, entonces su SVD esta representada por:
#
# \begin{align}
# \underset{n\times k}{\underbrace{X}}=\underset{n\times n}{\underbrace{U}}\underset{n\times k}{\underbrace{S}}\underset{k\times k}{\underbrace{V'}}
# \end{align}
#
# 1. $U$ es una matriz $n\times n$ cuyas columnas son ortogonales $(U'U=I_{n})$, y donde las columnas de $U$ son los vectores singulares de la izquierda
# 2. $V$ es una matriz $k\times k$ cuyas filas y columnas son  ortogonales $(V'V=VV'=I_{k})$, y las columnas de V son los vectores singulares de la derecha.
# 3. $S$ es una matriz $n\times k$ que contiene los $r=min(n,k)$ valores singulares $(\sigma_{i}\geq0)$ en la diagonal principal, y 0 en el resto de la matriz.

# %% [markdown]
# Para ilustrar como funciona la descomposición geométricamente, supongamos que tenemos un círculo en 2 dimensiones, representado por 2 vectores $v_1$ y $v_2$ como lo muestra la siguiente figura:

# %% [markdown]
# <div style="max-width:500px">
# <img src = "figs/rot1.png" />
# </div>

# %% [markdown]
# La SVD implica aplicar una transformación matricial a estos dos vectores de forma tal que vamos a obtener dos nuevos vectores $\sigma_1 u_1$ y $\sigma_2 u_2$:
#
# \begin{align}
# XV=US
# \end{align}
# donde V es la matriz cuyas columnas son los vectores $v_1$ y $v_2$, $X$ es la matriz de datos, S la matriz diagonal de $\sigma_1$ y $\sigma_2$ y U la matriz de los vectores $u_1$ y $u_2$. Esta transformación equivale a "estirar" el círculo como lo muestra la siguiente figura:

# %% [markdown]
# <div style="max-width:500px">
# <img src = "figs/rot2.png" />
# </div>

# %% [markdown]
# En este caso los valores singulars $\sigma$ son los factores que estiran. Notemos además que las columnas de $V$ son ortogonales, por lo que podemos hacer:
#
# \begin{align}
# XV&=US \\
# XVV'&=USV' \\
# X &=USV'
# \end{align}
#
# donde obtenemos la expresión original.

# %% [markdown]
# ### Ejemplo
#
# Miremos un ejemplo sencillo para illustrar el cálculo de SVD. Comenzamos con la siguiente matriz $X$:
#
#
# \begin{align}
# X=\left(\begin{array}{cc}
# 7 & 3\\
# 3 & -1
# \end{array}\right)
# \end{align}
#
# partiendo de la ecuación $(X-\lambda I)x=0$, podemos obtener el polinomio
# característico,
#
# \begin{align}
# \lambda^{2}-6\lambda-16=0
# \end{align}
#
# resolviendo tenemos que los eigenvalues son
#
# \begin{align}
# \lambda_{1}=8
# \end{align}
#
# y
#
# \begin{align}
# \lambda_{2}=-2
# \end{align}
#
# luego necesitamos los eigenvectores. El eigenvector asociado con $\lambda_{1}=8$,
# será
#
# \begin{align}
# Xv^{1}=\lambda_{1}v^{1}
# \end{align}
#
# \begin{align}
# \left(X-\lambda_{1}I\right)v^{1}=0
# \end{align}
#
# \begin{align}
# \left(\left(\begin{array}{cc}
# 7 & 3\\
# 3 & -1
# \end{array}\right)-\left(\begin{array}{cc}
# \lambda_{1} & 0\\
# 0 & \lambda_{1}
# \end{array}\right)\right)v^{1}=0
# \end{align}
#
# \begin{align}
# \left(\begin{array}{cc}
# -1 & 3\\
# 3 & -9
# \end{array}\right)\left(\begin{array}{c}
# v_{1}^{1}\\
# v_{2}^{2}
# \end{array}\right)=0
# \end{align}
#
# \begin{align}
# -1v_{11}+3v_{21}=0
# \end{align}
#
# \begin{align}
# 3v_{11}-9v_{21}=0
# \end{align}
#
# Entonces podemos ver que $v_{1}^{1}=3v_{2}^{1}$ , sin perdida de
# generalidad podemos fijar $v_{2}^{1}=1$, entonces el eigenvector
# asociado a este eigenvalor es
#
# \begin{align}
# v^{1}=\left(\begin{array}{c}
# 3\\
# 1
# \end{array}\right)
# \end{align}
#
# Normalizando para que el vector tenga dimensión 1 (dividimos por $\sqrt{3^{2}+1^{2}}$)
#
# \begin{align}
# v^{1}=\left(\begin{array}{c}
# 0.9486\\
# 0.3162
# \end{array}\right)
# \end{align}
#
# Del mismo modo procedemos para el eigenvector asociado con $\lambda_{2}=-2$,
# será
#
# \begin{align}
# \left(X-\lambda_{2}I\right)v^{2}=0
# \end{align}
#
# \begin{align}
# \left(\left(\begin{array}{cc}
# 7 & 3\\
# 3 & -1
# \end{array}\right)-\left(\begin{array}{cc}
# \lambda_{2} & 0\\
# 0 & \lambda_{2}
# \end{array}\right)\right)v^{2}=0
# \end{align}
#
# \begin{align}
# \left(\begin{array}{cc}
# 9 & 3\\
# 3 & 1
# \end{array}\right)\left(\begin{array}{c}
# v_{1}^{2}\\
# v_{2}^{2}
# \end{array}\right)=0
# \end{align}
#
# \begin{align}
# 9v_{1}^{2}+3v_{2}^{2}=0
# \end{align}
#
# \begin{align}
# 3v_{1}^{2}-1v_{2}^{2}=0
# \end{align}
#
# De este sistema de ecuaciones podemos ver que $-3v_{1}^{2}=v_{2}^{2}$
# , y fijando $v_{1}^{2}=1$, tenemos el eigenvector normalizado asociado
#
# \begin{align}
# v^{2}=\left(\begin{array}{c}
# 0.3162\\
# -0.9486
# \end{array}\right)
# \end{align}
#
# Recordando del cuaderno de *Descomposición en Valores Singulares. Fundamentos Teóricos.* la conexión entre SVD y eigenvalores,  podemos obtener la matriz $S$:
#
# \begin{align}
# S=\left(\begin{array}{cc}
# 8 & 0\\
# 0 & 2
# \end{array}\right)
# \end{align}
#
# y la matriz V
#
# \begin{align}
# V=\left(\begin{array}{cc}
# 0.9486 & 0.3162\\
# 0.3162 & -0.9486
# \end{array}\right)
# \end{align}
#
# Para completar la SVD $(X=USV')$ necesitamos computar $U$, o cual podemos hacer con la formula $\sigma_{i}u^{i}=Xv^{1}$
#
# \begin{align}
# u^{1}=\frac{1}{8}\left(\begin{array}{cc}
# 7 & 3\\
# 3 & -1
# \end{array}\right)\left(\begin{array}{c}
# 0.9486\\
# 0.3162
# \end{array}\right)=\left(\begin{array}{c}
# 0.9486\\
# 0.3162
# \end{array}\right)
# \end{align}
#
# \begin{align}
# u^{2}=\left(\frac{1}{2}\right)\left(\begin{array}{cc}
# 7 & 3\\
# 3 & -1
# \end{array}\right)\left(\begin{array}{c}
# 0.3162\\
# -0.9486
# \end{array}\right)=\left(\begin{array}{c}
# 0.3162\\
# -0.9486
# \end{array}\right)
# \end{align}
#
# Con esto podemos completar $U$
#
# \begin{align}
# \left(\begin{array}{cc}
# 0.9486 & 0.3162\\
# 0.3162 & -0.9486
# \end{array}\right)
# \end{align}

# %% [markdown]
# Note, que en este caso nos dio una matriz igual a $V$. Rara vez tendremos que resolver esta descomposición con papel y lápiz, lo haremos generalmente en `Python`. Verifiquemos entonces, los resultados obtenidos en `Python`:

# %%
import numpy as np # llamamos numpy
from scipy.linalg import svd # Cargamos la función SVD

X = np.array([[7, 3], 
              [3, -1]])

X
# Out:
# array([[ 7,  3],
#        [ 3, -1]])

# %%
U, S, V = svd(X)

# %%
print('U=', U)
# Out:
# U= [[-0.9486833  -0.31622777]
#  [-0.31622777  0.9486833 ]]

# %%
print('S=', S)
# Out:
# S= [8. 2.]

# %%
print('V=', V)
# Out:
# V= [[-0.9486833  -0.31622777]
#  [ 0.31622777 -0.9486833 ]]

# %% [markdown]
# Note que los resultados son los mismos excepto por el cambio de signo. Esto tiene que ver con cómo computa `Python` los eigenvectores. Con estos podemos entonces reconstruir $X$ usando la ecuación $X =USV'$

# %%
X_reconstruida = U @ np.diag(S) @ V
X_reconstruida
# Out:
# array([[ 7.,  3.],
#        [ 3., -1.]])

# %% [markdown]
# Podemos tambien verificar la relación entre SVD y eigenvalores:

# %%
eig_val, eig_vec = np.linalg.eig(X@X.T)
eig_val
np.sqrt(eig_val)
# Out:
# array([8., 2.])

# %% [markdown]
# ## Ejercicios teóricos
#
#
# Resuelva los siguientes problemas. Intente realizarlos primero sin ayuda de `Python` y luego verifique su solución con los comandos de `Python`.

# %% [markdown]
# 1. Demuestre que la Descomposición en Valores Singulares encuentra la dirección para la cual la matriz original estira más el vector unitario. Parta de la siguiente expresión:
# $$argmax_{x:||x||=1} ||Bx||$$
# 2. $B$ es una matriz cuadrada de tamaño $m\times m$, cuyas filas son ortonormales. Demuestre que las columnas de $B$ también son ortonormales.
# 3. Suponga que $C$ es una matriz cuadrada invertible y que la Descomposición en Valores Singulares de $C$ es $C=\sum_i \sigma_i u_i v_i'$. Encuentre la inversa de $C$.
# 4. Encuentre la SVD de la matriz $A$, $U S V'$, en donde $A = \begin{bmatrix} 3 & 2 & 2 \\ 2 & 3 & -2 \end{bmatrix}$
# 5. Demuestre que los vectores singulares izquierdos de una matriz $D$ son los vectores singulares derechos de $D'$

# %%
#Solución 1
import numpy as np

B = np.array([[3,2,2],[2,3,-2]])
_, S, Vt = np.linalg.svd(B)
v1 = Vt[0]

print('sigma_1 =', S[0])
print('||B v1|| =', np.linalg.norm(B @ v1))
# Out:
# sigma_1 = 4.999999999999999
# ||B v1|| = 5.000000000000001

# %%
#Solución 2
import numpy as np

t = np.pi/6
B = np.array([[np.cos(t), -np.sin(t)],
              [np.sin(t),  np.cos(t)]])

print('B B^T =\n', np.round(B @ B.T, 5))
print('B^T B =\n', np.round(B.T @ B, 5))
# Out:
# B B^T =
#  [[ 1. -0.]
#  [-0.  1.]]
# B^T B =
#  [[1. 0.]
#  [0. 1.]]

# %%
#Solución 3
import numpy as np

C = np.array([[4,0],[3,5]])
U, S, Vt = np.linalg.svd(C)

C_inv_svd   = Vt.T @ np.diag(1/S) @ U.T
C_inv_numpy = np.linalg.inv(C)

print('Inversa via SVD:\n', np.round(C_inv_svd, 4))
print('Inversa via numpy:\n', np.round(C_inv_numpy, 4))
# Out:
# Inversa via SVD:
#  [[ 0.25 -0.  ]
#  [-0.15  0.2 ]]
# Inversa via numpy:
#  [[ 0.25  0.  ]
#  [-0.15  0.2 ]]

# %%
#Solución 4
import numpy as np

A = np.array([[3,2,2],[2,3,-2]])
U, S, Vt = np.linalg.svd(A)

print('U =\n', np.round(U, 3))
print('S =', np.round(S, 3))
print('V =\n', np.round(Vt.T, 3))
# Out:
# U =
#  [[-0.707 -0.707]
#  [-0.707  0.707]]
# S = [5. 3.]
# V =
#  [[-0.707 -0.236 -0.667]
#  [-0.707  0.236  0.667]
#  [-0.    -0.943  0.333]]

# %%
#Solución 5
import numpy as np

D = np.array([[3,2,2],[2,3,-2]])
U, S, Vt = np.linalg.svd(D)
U2, S2, Vt2 = np.linalg.svd(D.T)

print('V de D:\n', np.round(Vt.T, 3))
print('U de D transpuesta:\n', np.round(U2, 3))
# Out:
# V de D:
#  [[-0.707 -0.236 -0.667]
#  [-0.707  0.236  0.667]
#  [-0.    -0.943  0.333]]
# U de D transpuesta:
#  [[-0.707  0.236 -0.667]
#  [-0.707 -0.236  0.667]
#  [-0.     0.943  0.333]]

# %% [markdown]
# # Información de Sesión

# %%
import session_info

session_info.show(html=False)
